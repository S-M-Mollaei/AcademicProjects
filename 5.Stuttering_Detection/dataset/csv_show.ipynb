# %%
import pandas as pd

# %%
df = pd.read_csv('./1.data_preparation_7_all_noConfidence_balanced_target.csv')
df.head()
# Out:
#    downsampling_rate  frame_length_in_s  frame_step_in_s  num_mel_bins  \
# 0              16000              0.008            0.008            40
# 1              16000              0.008            0.008            40
# 2              16000              0.008            0.008            40
# 3              16000              0.008            0.008            40
# 4              16000              0.008            0.008            40
#
#    num_coefficients  lower_frequency  upper_frequency  batch_size  \
# 0                20               20             8000          20
# 1                20               20             8000          20
# 2                20               20             8000          20
# 3                20               20             8000          20
# 4                20               20             8000          64
#
#    initial_learning_rate  end_learning_rate  ...  initial_sparsity  \
# 0                   0.01            0.00001  ...               0.2
# ...

# %%
df[df['fluency_f1']>=60]
# Out:
#      downsampling_rate  frame_length_in_s  frame_step_in_s  num_mel_bins  \
# 104              16000              0.032            0.016            40
# 116              16000              0.032            0.016            40
# 129              16000              0.032            0.032            40
# 141              16000              0.032            0.032            40
#
#      num_coefficients  lower_frequency  upper_frequency  batch_size  \
# 104                20               20             8000         128
# 116                40               20             8000         128
# 129                20               20             8000         128
# 141                40               20             8000         128
#
#      initial_learning_rate  end_learning_rate  ...  initial_sparsity  \
# 104                   0.01            0.00001  ...               0.2
# 116                   0.01            0.00001  ...               0.2
# ...

# %%
df[(df['fluency_accuracy']>=60) & (df['fluency_f1']>=59)]
# Out:
#     downsampling_rate  frame_length_in_s  frame_step_in_s  num_mel_bins  \
# 72              16000              0.032            0.008            40
# 84              16000              0.032            0.008            40
#
#     num_coefficients  lower_frequency  upper_frequency  batch_size  \
# 72                20               20             8000          20
# 84                40               20             8000          20
#
#     initial_learning_rate  end_learning_rate  ...  initial_sparsity  \
# 72                   0.01            0.00001  ...               0.2
# 84                   0.01            0.00001  ...               0.2
#
#     final_sparsity  training_accuracy_tf  validation_accuracy_tf  \
# 72             0.6             76.442397               69.174039
# 84             0.6             76.442397               69.174039
#
#     test_accuracy_tf  fluency_accuracy   sep28_f1  fluency_f1  \
# 72         68.879056         61.218989  49.775112   59.325843
# ...

# %%
df[(df['fluency_accuracy']>=67)]
# Out:
#      downsampling_rate  frame_length_in_s  frame_step_in_s  num_mel_bins  \
# 273              32000              0.032            0.032            40
# 285              32000              0.032            0.032            40
#
#      num_coefficients  lower_frequency  upper_frequency  batch_size  \
# 273                20               20            16000         128
# 285                40               20            16000         128
#
#      initial_learning_rate  end_learning_rate  ...  initial_sparsity  \
# 273                   0.01            0.00001  ...               0.2
# 285                   0.01            0.00001  ...               0.2
#
#      final_sparsity  training_accuracy_tf  validation_accuracy_tf  \
# 273             0.6             78.838712               71.238941
# 285             0.6             78.838712               71.238941
#
#      test_accuracy_tf  fluency_accuracy   sep28_f1  fluency_f1  \
# ...

# %%
df[df['test_accuracy_tf']>=74]
# Out:
#      downsampling_rate  frame_length_in_s  frame_step_in_s  num_mel_bins  \
# 121              16000              0.032            0.032            40
# 133              16000              0.032            0.032            40
# 363              48000              0.032            0.008            40
# 375              48000              0.032            0.008            40
# 387              48000              0.032            0.016            40
# 399              48000              0.032            0.016            40
#
#      num_coefficients  lower_frequency  upper_frequency  batch_size  \
# 121                20               20             8000          20
# 133                40               20             8000          20
# 363                20               20            24000          20
# 375                40               20            24000          20
# 387                20               20            24000          20
# ...

# %%
df[(df['test_accuracy_tf']>=72) & (df['model_filter']==64) & (df['downsampling_rate']==16000)]
# Out:
#      downsampling_rate  frame_length_in_s  frame_step_in_s  num_mel_bins  \
# 122              16000              0.032            0.032            40
# 134              16000              0.032            0.032            40
#
#      num_coefficients  lower_frequency  upper_frequency  batch_size  \
# 122                20               20             8000          20
# 134                40               20             8000          20
#
#      initial_learning_rate  end_learning_rate  ...  initial_sparsity  \
# 122                   0.01            0.00001  ...               0.2
# 134                   0.01            0.00001  ...               0.2
#
#      final_sparsity  training_accuracy_tf  validation_accuracy_tf  \
# 122             0.6             76.479262               71.091443
# 134             0.6             76.479262               71.091443
#
#      test_accuracy_tf  fluency_accuracy   sep28_f1  fluency_f1  \
# ...

# %%
print(df.iloc[28])
# YES
# Out:
# downsampling_rate         16000.000000
# frame_length_in_s             0.016000
# frame_step_in_s               0.008000
# num_mel_bins                 40.000000
# num_coefficients             20.000000
# lower_frequency              20.000000
# upper_frequency            8000.000000
# batch_size                   64.000000
# initial_learning_rate         0.010000
# end_learning_rate             0.000010
# epochs                       20.000000
# model_filter                 64.000000
# alpha                         0.200000
# initial_sparsity              0.200000
# final_sparsity                0.600000
# training_accuracy_tf         78.193551
# validation_accuracy_tf       72.271389
# test_accuracy_tf             70.943952
# fluency_accuracy             66.127294
# sep28_f1                     51.519537
# fluency_f1                   50.639659
# tflite_model_size            19.722656
# tflite_zip_model_size        13.173828
# Name: 28, dtype: float64

# %%
print(df.iloc[122])
# NO
# Out:
# downsampling_rate         16000.000000
# frame_length_in_s             0.032000
# frame_step_in_s               0.032000
# num_mel_bins                 40.000000
# num_coefficients             20.000000
# lower_frequency              20.000000
# upper_frequency            8000.000000
# batch_size                   20.000000
# initial_learning_rate         0.010000
# end_learning_rate             0.000010
# epochs                       30.000000
# model_filter                 64.000000
# alpha                         0.200000
# initial_sparsity              0.200000
# final_sparsity                0.600000
# training_accuracy_tf         76.479262
# validation_accuracy_tf       71.091443
# test_accuracy_tf             72.713864
# fluency_accuracy             64.131606
# sep28_f1                     51.908397
# fluency_f1                   43.172332
# tflite_model_size            19.785156
# tflite_zip_model_size        13.201172
# Name: 122, dtype: float64

# %%
print(df.iloc[121])
# NO BUT FINAL ONE
# Out:
# downsampling_rate         16000.000000
# frame_length_in_s             0.032000
# frame_step_in_s               0.032000
# num_mel_bins                 40.000000
# num_coefficients             20.000000
# lower_frequency              20.000000
# upper_frequency            8000.000000
# batch_size                   20.000000
# initial_learning_rate         0.010000
# end_learning_rate             0.000010
# epochs                       20.000000
# model_filter                128.000000
# alpha                         0.200000
# initial_sparsity              0.200000
# final_sparsity                0.600000
# training_accuracy_tf         78.193551
# validation_accuracy_tf       72.123891
# test_accuracy_tf             74.336284
# fluency_accuracy             65.048546
# sep28_f1                     49.541284
# fluency_f1                   46.628571
# tflite_model_size            54.519531
# tflite_zip_model_size        45.637695
# Name: 121, dtype: float64
